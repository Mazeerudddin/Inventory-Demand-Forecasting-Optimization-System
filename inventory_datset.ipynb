# %% [markdown]
# DATA CLEANING

# %%
import pandas as pd  # library used for data manupulation
import numpy as np   # library used for arithematic


df=pd.read_csv("retail_store_inventory.csv") # create a dataframe to read the this csv file ,use "relative path "
# %store df
# Out:
# Stored 'df' (DataFrame)

# %%
print(df.head()) # first 5 rows

print(df.info()) #column info

print(df.isnull().sum()) #identify the number of missing values in eacch column

df=df.dropna() # drops all nA values   ''' only use on usless column 

'''if missing values found then use lets say column [age] has missing vals

FOR NUMERICAL COLUMN -

df["Age"] = df["Age"].fillna(df["Age"].mean())

FOR TEXT COLUMN -
df["city'] = df["city"].fillna("unknown")'''

df=df.drop_duplicates() # deletes duplicate values

df["Customer_Name"] = df["Customer_Name"].str.strip()  # remove unwanted spaces

df[col_name] = df[clumn_name].str.lower() #lower case or upper case

df=df[df[col_name]>0] #remove invalid data likely umerical

df.to_csv("project_mck\retail_store_inventory.csv",index =false)

# %%
df.to_csv("mck_retail_proj.csv",index =False)
print("data cleaning completed")
# Out:
# data cleaning completed
